# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from encodings.aliases import aliases 

# %matplotlib inline

# %%
alias_values = set(aliases.values())

for encoding in set(aliases.values()):
    try:
        df=pd.read_csv("crime.csv", nrows=10, encoding=encoding) 
        print('successful', encoding)
    except:
        pass
# Out:
# successful iso8859_4
# successful iso8859_7
# successful cp1251
# successful cp775
# successful utf_16_be
# successful cp1140
# successful cp852
# successful utf_16_le
# successful cp1258
# successful cp932
# successful cp850
# successful iso8859_8
# successful gbk
# successful mac_latin2
# successful cp1125
# successful cp1250
# successful cp1252
# successful mac_iceland
# successful hp_roman8
# successful iso8859_16
# successful cp037
# successful iso8859_6
# successful mac_turkish
# successful iso8859_2
# successful cp273
# successful koi8_r
# successful iso8859_9
# successful cp864
# successful iso8859_5
# successful cp869
# successful cp861
# successful mac_greek
# successful cp1256
# successful cp1257
# successful iso8859_11
# successful cp858
# successful gb18030
# successful iso8859_15
# successful cp863
# successful iso8859_10
# successful latin_1
# successful big5hkscs
# successful cp1254
# successful cp500
# successful iso8859_3
# successful iso8859_13
# successful cp437
# ...

# %%
crime = pd.read_csv("crime.csv", encoding="ISO-8859-11")

# %%
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
#Explore the number of rows and columns in dataset
crime.shape
# Out:
# (319073, 17)

# %%
#Check for any duplicated rows
crime.duplicated().sum()
# Out:
# 23

# %%
crime.drop_duplicates(inplace=True)

# %%
#Check whether duplicated rows have been dropped
crime.shape
# Out:
# (319050, 17)

# %%
#View start of dataset
crime.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
#View end of dataset
crime.tail()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 319068   I050310906-00          3125    Warrant Arrests
# 319069   I030217815-08           111           Homicide
# 319070   I030217815-08          3125    Warrant Arrests
# 319071   I010370257-00          3125    Warrant Arrests
# 319072       142052550          3125    Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 319068                       WARRANT ARREST       D4            285      NaN
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18            520      NaN
# 319070                       WARRANT ARREST      E18            520      NaN
# 319071                       WARRANT ARREST      E13            569      NaN
# 319072                       WARRANT ARREST       D4            903      NaN
#
#            OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 319068  2016-06-05 17:25:00  2016      6      Sunday    17  Part Three
# ...

# %%
#View the summary and column information
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319050 entries, 0 to 319072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319050 non-null  object
#  1   OFFENSE_CODE         319050 non-null  int64
#  2   OFFENSE_CODE_GROUP   319050 non-null  object
#  3   OFFENSE_DESCRIPTION  319050 non-null  object
#  4   DISTRICT             317285 non-null  object
#  5   REPORTING_AREA       319050 non-null  object
#  6   SHOOTING             1019 non-null    object
#  7   OCCURRED_ON_DATE     319050 non-null  object
#  8   YEAR                 319050 non-null  int64
#  9   MONTH                319050 non-null  int64
#  10  DAY_OF_WEEK          319050 non-null  object
#  11  HOUR                 319050 non-null  int64
#  12  UCR_PART             318960 non-null  object
#  13  STREET               308179 non-null  object
#  14  Lat                  299052 non-null  float64
# ...

# %%
#View the start and end of dataset at once
crime
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14            808      NaN
# 1                                 VANDALISM      C11            347      NaN
# ...

# %%
#Change OCCURRED_ON_DATE column to a datetime data type
crime.OCCURRED_ON_DATE = pd.to_datetime(crime.OCCURRED_ON_DATE)

# %%
#Check whether data type has been changed 
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319050 entries, 0 to 319072
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   INCIDENT_NUMBER      319050 non-null  object
#  1   OFFENSE_CODE         319050 non-null  int64
#  2   OFFENSE_CODE_GROUP   319050 non-null  object
#  3   OFFENSE_DESCRIPTION  319050 non-null  object
#  4   DISTRICT             317285 non-null  object
#  5   REPORTING_AREA       319050 non-null  object
#  6   SHOOTING             1019 non-null    object
#  7   OCCURRED_ON_DATE     319050 non-null  datetime64[ns]
#  8   YEAR                 319050 non-null  int64
#  9   MONTH                319050 non-null  int64
#  10  DAY_OF_WEEK          319050 non-null  object
#  11  HOUR                 319050 non-null  int64
#  12  UCR_PART             318960 non-null  object
#  13  STREET               308179 non-null  object
# ...

# %%
#Extract year from the OCCURRED_ON_DATE column
crime.OCCURRED_ON_DATE.dt.year
# Out:
# 0         2018
# 1         2018
# 2         2018
# 3         2018
# 4         2018
#           ...
# 319068    2016
# 319069    2015
# 319070    2015
# 319071    2016
# 319072    2015
# Name: OCCURRED_ON_DATE, Length: 319050, dtype: int64

# %%
#extract month from the OCCURRED_ON_DATE column
crime.OCCURRED_ON_DATE.dt.month
# Out:
# 0         9
# 1         8
# 2         9
# 3         9
# 4         9
#          ..
# 319068    6
# 319069    7
# 319070    7
# 319071    5
# 319072    6
# Name: OCCURRED_ON_DATE, Length: 319050, dtype: int64

# %%
#extract week from the OCCURRED_ON_DATE column
crime.OCCURRED_ON_DATE.dt.week
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11572\142951713.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   crime.OCCURRED_ON_DATE.dt.week
# 0         35
# 1         34
# 2         36
# 3         36
# 4         36
#           ..
# 319068    22
# 319069    28
# 319070    28
# 319071    22
# 319072    26
# Name: OCCURRED_ON_DATE, Length: 319050, dtype: int64

# %%
#extract hour from the OCCURRED_ON_DATE column
crime.OCCURRED_ON_DATE.dt.hour
# Out:
# 0         13
# 1          0
# 2         19
# 3         21
# 4         21
#           ..
# 319068    17
# 319069    13
# 319070    13
# 319071    19
# 319072     0
# Name: OCCURRED_ON_DATE, Length: 319050, dtype: int64

# %%
#extract minute from the OCCURRED_ON_DATE column
crime.OCCURRED_ON_DATE.dt.minute
# Out:
# 0          0
# 1          0
# 2         27
# 3         16
# 4          5
#           ..
# 319068    25
# 319069    38
# 319070    38
# 319071    35
# 319072    12
# Name: OCCURRED_ON_DATE, Length: 319050, dtype: int64

# %%
#View summary stats on numeric columns
crime.describe()
# Out:
#         OFFENSE_CODE           YEAR          MONTH           HOUR  \
# count  319050.000000  319050.000000  319050.000000  319050.000000
# mean     2317.516957    2016.560674       6.609622      13.118176
# std      1185.308921       0.996312       3.273677       6.294258
# min       111.000000    2015.000000       1.000000       0.000000
# 25%      1001.000000    2016.000000       4.000000       9.000000
# 50%      2907.000000    2017.000000       7.000000      14.000000
# 75%      3201.000000    2017.000000       9.000000      18.000000
# max      3831.000000    2018.000000      12.000000      23.000000
#
#                  Lat           Long
# count  299052.000000  299052.000000
# mean       42.214373     -70.908260
# std         2.159845       3.493746
# min        -1.000000     -71.178674
# 25%        42.297438     -71.097135
# 50%        42.325538     -71.077524
# 75%        42.348624     -71.062467
# max        42.395042      -1.000000

# %%
#View summary stats on non-numeric columns
crime.describe(include='object')
# Out:
#        INCIDENT_NUMBER               OFFENSE_CODE_GROUP  \
# count           319050                           319050
# unique          282517                               67
# top         I162030584  Motor Vehicle Accident Response
# freq                13                            37132
#
#                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# count                          319050   317285         319050     1019
# unique                            244       12            879        1
# top     SICK/INJURED/MEDICAL - PERSON       B2                       Y
# freq                            18783    49940          20250     1019
#
#        DAY_OF_WEEK    UCR_PART         STREET                  Location
# count       319050      318960         308179                    319050
# unique           7           4           4657                     18194
# top         Friday  Part Three  WASHINGTON ST  (0.00000000, 0.00000000)
# ...

# %%
#View dataset columns
crime.columns
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
#Check for columns with missing values
crime.columns[np.sum(crime.isnull())!=0]
# Out:
# Index(['DISTRICT', 'SHOOTING', 'UCR_PART', 'STREET', 'Lat', 'Long'], dtype='object')

# %%
#Check for columns with no missing values
crime.columns[np.sum(crime.isnull())==0]
# Out:
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'YEAR',
#        'MONTH', 'DAY_OF_WEEK', 'HOUR', 'Location'],
#       dtype='object')

# %%
#Check for number of unique values
for col in crime.columns:
    unique_count=crime[col].nunique()
    print(col+ 'has' + str(unique_count) + 'unique values')
# Out:
# INCIDENT_NUMBERhas282517unique values
# OFFENSE_CODEhas222unique values
# OFFENSE_CODE_GROUPhas67unique values
# OFFENSE_DESCRIPTIONhas244unique values
# DISTRICThas12unique values
# REPORTING_AREAhas879unique values
# SHOOTINGhas1unique values
# OCCURRED_ON_DATEhas233229unique values
# YEARhas4unique values
# MONTHhas12unique values
# DAY_OF_WEEKhas7unique values
# HOURhas24unique values
# UCR_PARThas4unique values
# STREEThas4657unique values
# Lathas18178unique values
# Longhas18178unique values
# Locationhas18194unique values

# %%
#What is the most common crime in terms of OFFENCE_CODE_GROUP
crime.OFFENSE_CODE_GROUP.value_counts()
# Out:
# Motor Vehicle Accident Response              37132
# Larceny                                      25935
# Medical Assistance                           23540
# Investigate Person                           18749
# Other                                        18073
#                                              ...
# HUMAN TRAFFICKING                                7
# INVESTIGATE PERSON                               4
# Biological Threat                                2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %%
#View top 10 common crimes
crime.OFFENSE_CODE_GROUP.value_counts()[:10]
# Out:
# Motor Vehicle Accident Response    37132
# Larceny                            25935
# Medical Assistance                 23540
# Investigate Person                 18749
# Other                              18073
# Drug Violation                     16545
# Simple Assault                     15826
# Vandalism                          15414
# Verbal Disputes                    13099
# Towed                              11287
# Name: OFFENSE_CODE_GROUP, dtype: int64

# %%
#View bottom 10 least common crimes 
crime.OFFENSE_CODE_GROUP.value_counts().sort_values(ascending=True)[:10]
# Out:
# Burglary - No Property Taken                  2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE     2
# Biological Threat                             2
# INVESTIGATE PERSON                            4
# HUMAN TRAFFICKING                             7
# Gambling                                      8
# Manslaughter                                  8
# Explosives                                   27
# Phone Call Complaints                        31
# Aircraft                                     36
# Name: OFFENSE_CODE_GROUP, dtype: int64

# %%
#Display a bar chart of the top 10 most common types of crimes in terms of OFFENCE_CODE_GROUP
offense_group_vals = crime.OFFENSE_CODE_GROUP.value_counts()[:10]

display(offense_group_vals / crime.shape[0])

# Creating a bar chart of the Top 10 offense groups
(offense_group_vals / crime.shape[0]).plot(kind='bar');
plt.title('Top 10 Offense Groups (as % of all crimes)');
# Out:
# Motor Vehicle Accident Response    0.116383
# Larceny                            0.081288
# Medical Assistance                 0.073782
# Investigate Person                 0.058765
# Other                              0.056646
# Drug Violation                     0.051857
# Simple Assault                     0.049604
# Vandalism                          0.048312
# Verbal Disputes                    0.041056
# Towed                              0.035377
# Name: OFFENSE_CODE_GROUP, dtype: float64

# %%
#Display a bar chart of the bottom 10 most  types of crimes in terms of OFFENCE_CODE_GROUP
offense_group_vals = crime.OFFENSE_CODE_GROUP.value_counts().sort_values(ascending=True)[:10]
display(offense_group_vals / crime.shape[0])

# Creating a bar chart of the Top 10 offense groups
(offense_group_vals / crime.shape[0]).plot(kind='bar');
plt.title('Bottom 10 Offense Groups (as % of all crimes)');
# Out:
# Burglary - No Property Taken                 0.000006
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE    0.000006
# Biological Threat                            0.000006
# INVESTIGATE PERSON                           0.000013
# HUMAN TRAFFICKING                            0.000022
# Gambling                                     0.000025
# Manslaughter                                 0.000025
# Explosives                                   0.000085
# Phone Call Complaints                        0.000097
# Aircraft                                     0.000113
# Name: OFFENSE_CODE_GROUP, dtype: float64

# %%
# Out:
# DRUGS - POSS CLASS D - INTENT MFR DIST DISP    0.000003
# PROSTITUTE - COMMON NIGHTWALKER                0.000003
# B&E NON-RESIDENCE NIGHT - FORCE                0.000003
# ROBBERY - UNARMED - BUSINESS                   0.000003
# B&E RESIDENCE DAY - NO FORCE                   0.000003
# B&E NON-RESIDENCE DAY - NO PROP TAKEN          0.000003
# ROBBERY - UNARMED - RESIDENCE                  0.000003
# PRISONER ATTEMPT TO RESCUE                     0.000003
# ASSAULT & BATTERY D/W - KNIFE                  0.000003
# B&E RESIDENCE DAY - NO PROP TAKEN              0.000003
# Name: OFFENSE_DESCRIPTION, dtype: float64

# %%
#Most common offence descriptions
crime.OFFENSE_DESCRIPTION.value_counts()
# Out:
# SICK/INJURED/MEDICAL - PERSON                  18783
# INVESTIGATE PERSON                             18753
# M/V - LEAVING SCENE - PROPERTY DAMAGE          16323
# VANDALISM                                      15153
# ASSAULT SIMPLE - BATTERY                       14791
#                                                ...
# KILLING OF FELON BY POLICE                         1
# AUTO THEFT - OUTSIDE - RECOVERED IN BOSTON         1
# DRUGS - GLUE INHALATION                            1
# ROBBERY - KNIFE - STREET                           1
# DRUGS - POSS CLASS D - INTENT MFR DIST DISP        1
# Name: OFFENSE_DESCRIPTION, Length: 244, dtype: int64

# %%
#Bar chart displaying the TOP 10 most common offence desription in terms of OFFENCE_DESCRIPTION
description_group_vals=crime.OFFENSE_DESCRIPTION.value_counts()[:10]
display(description_group_vals / crime.shape[0])

(description_group_vals / crime.shape[0]).plot(kind='bar');
plt.title('TOP 10 Offense Description Groups (as % of all crimes)');
# Out:
# SICK/INJURED/MEDICAL - PERSON            0.058872
# INVESTIGATE PERSON                       0.058778
# M/V - LEAVING SCENE - PROPERTY DAMAGE    0.051161
# VANDALISM                                0.047494
# ASSAULT SIMPLE - BATTERY                 0.046360
# VERBAL DISPUTE                           0.041056
# TOWED MOTOR VEHICLE                      0.035377
# INVESTIGATE PROPERTY                     0.034866
# LARCENY THEFT FROM BUILDING              0.028425
# THREATS TO DO BODILY HARM                0.028340
# Name: OFFENSE_DESCRIPTION, dtype: float64

# %%
#Total number of crimes per year
crime.groupby('YEAR').count()['INCIDENT_NUMBER']
# Out:
# YEAR
# 2015     53371
# 2016     99110
# 2017    100884
# 2018     65685
# Name: INCIDENT_NUMBER, dtype: int64

# %%
crime.groupby('YEAR').count()['INCIDENT_NUMBER'].plot(kind='bar')
plt.title('Number of Incidents per Year')
# Out:
# Text(0.5, 1.0, 'Number of Incidents per Year')

# %%
#Number of crimes committed per day
#Display number of crimes per day info
display(crime.groupby('DAY_OF_WEEK').count()['INCIDENT_NUMBER'].sort_values(ascending=False))

#Show results in pie chart
crime.groupby('DAY_OF_WEEK').count()['INCIDENT_NUMBER'].sort_values(ascending=False).plot(kind='bar')
plt.title('Crimes per Day')
# Out:
# DAY_OF_WEEK
# Friday       48489
# Wednesday    46727
# Thursday     46655
# Tuesday      46376
# Monday       45674
# Saturday     44816
# Sunday       40313
# Name: INCIDENT_NUMBER, dtype: int64
# Text(0.5, 1.0, 'Crimes per Day')

# %%
#Number of crimes per hour
display(crime.groupby('HOUR').count()['INCIDENT_NUMBER'])
crime.groupby('HOUR').count()['INCIDENT_NUMBER'].plot(kind='bar')
plt.title('Crimes per Hour')
# Out:
# HOUR
# 0     15106
# 1      9267
# 2      7693
# 3      4589
# 4      3408
# 5      3311
# 6      5026
# 7      8850
# 8     13042
# 9     14740
# 10    16345
# 11    16445
# 12    18676
# 13    16845
# 14    17189
# 15    16519
# 16    19870
# 17    20762
# 18    20301
# 19    17587
# 20    15849
# 21    14109
# 22    12925
# 23    10596
# Name: INCIDENT_NUMBER, dtype: int64
# Text(0.5, 1.0, 'Crimes per Hour')

# %%
#Crimes per hour by day of week
crime.groupby(['HOUR','DAY_OF_WEEK']).count()['INCIDENT_NUMBER'].unstack()
# Out:
# DAY_OF_WEEK  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# HOUR
# 0              2161    2000      2612    2400      2039     1897       1997
# 1              1275    1058      1855    2043      1077     1017        942
# 2               952     846      1827    1855       774      641        798
# 3               532     583       957    1119       526      460        412
# 4               441     386       672     704       436      399        370
# 5               485     417       478     517       508      462        444
# 6               768     709       530     543       866      787        823
# 7              1398    1352      1078     758      1405     1418       1441
# 8              2041    2046      1515    1123      2037     2145       2135
# 9              2299    2148      1812    1457      2325     2322       2377
# 10             2668    2432      2064    1778      2496     2414       2493
# ...

# %%
week_and_hour=crime.groupby(['HOUR','DAY_OF_WEEK']).count()['INCIDENT_NUMBER'].unstack()

# %%
week_and_hour = week_and_hour[['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']]

# %%
#heatmap of the which hour within a day has most crimes
sns.heatmap(week_and_hour, cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: xlabel='DAY_OF_WEEK', ylabel='HOUR'>

# %%
#Average crimes committed per month
# if the value is less than the average crime per month, highlight the value in blue

avg_crime = crime.groupby(['YEAR', 'MONTH']).count()['INCIDENT_NUMBER'].mean()
print("The average number of crimes is " + str(avg_crime))

year_and_month = crime.groupby(['MONTH', 'YEAR']).count()['INCIDENT_NUMBER'].unstack()

def style_negative(v, props=''):
    return props if v < avg_crime else None
s2 = year_and_month.style.applymap(style_negative, props='color:blue;')\
              .applymap(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)
s2
# Out:
# The average number of crimes is 7976.25
# <style type="text/css">
# #T_878d8_row0_col1, #T_878d8_row0_col3, #T_878d8_row1_col1, #T_878d8_row1_col2, #T_878d8_row1_col3, #T_878d8_row2_col3, #T_878d8_row3_col3, #T_878d8_row5_col0, #T_878d8_row8_col3, #T_878d8_row10_col0, #T_878d8_row10_col1, #T_878d8_row10_col2, #T_878d8_row11_col1, #T_878d8_row11_col2 {
#   color: blue;
# }
# </style>
# <table id="T_878d8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_878d8_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_878d8_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_878d8_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_878d8_level0_col3" class="col_heading level0 col3" >2018</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MONTH</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
#Maximum number of accidents per month
# Use apply to highlight the maximum in a column in darkgreen

def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')
s2.apply(highlight_max, props='color:white;background-color:darkgreen', axis=0)
# Out:
# <style type="text/css">
# #T_878d8_row0_col1, #T_878d8_row0_col3, #T_878d8_row1_col1, #T_878d8_row1_col2, #T_878d8_row1_col3, #T_878d8_row2_col3, #T_878d8_row3_col3, #T_878d8_row5_col0, #T_878d8_row8_col3, #T_878d8_row10_col0, #T_878d8_row10_col1, #T_878d8_row10_col2, #T_878d8_row11_col1, #T_878d8_row11_col2 {
#   color: blue;
# }
# #T_878d8_row4_col3, #T_878d8_row7_col1, #T_878d8_row7_col2, #T_878d8_row8_col0 {
#   color: white;
#   background-color: darkgreen;
# }
# </style>
# <table id="T_878d8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_878d8_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_878d8_level0_col1" class="col_heading level0 col1" >2016</th>
#       <th id="T_878d8_level0_col2" class="col_heading level0 col2" >2017</th>
#       <th id="T_878d8_level0_col3" class="col_heading level0 col3" >2018</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >MONTH</th>
# ...

# %%
#Crimes per district
district_and_year=crime.groupby(['DISTRICT','YEAR']).count()['INCIDENT_NUMBER'].unstack()
sns.heatmap(district_and_year, cmap=sns.cubehelix_palette(as_cmap=True))
# Out:
# <Axes: xlabel='YEAR', ylabel='DISTRICT'>

# %%
#Average crime per district (if value is less than the average crime per district per year, values are highlighted in blue)

avg_crime_district = crime.groupby(['DISTRICT', 'YEAR']).count()['INCIDENT_NUMBER'].mean()
print("The average crime per district per year is: " + str(avg_crime_district))

def style_negative(v, props=''):
    return props if v < avg_crime_district else None
s3 = district_and_year.style.applymap(style_negative, props='color:blue;')\
              .applymap(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)
s3
# Out:
# The average crime per district per year is: 6610.104166666667
# <style type="text/css">
# #T_4dd38_row0_col0, #T_4dd38_row1_col0, #T_4dd38_row1_col1, #T_4dd38_row1_col2, #T_4dd38_row1_col3, #T_4dd38_row2_col0, #T_4dd38_row2_col1, #T_4dd38_row2_col2, #T_4dd38_row2_col3, #T_4dd38_row4_col0, #T_4dd38_row6_col0, #T_4dd38_row6_col3, #T_4dd38_row7_col0, #T_4dd38_row7_col1, #T_4dd38_row7_col2, #T_4dd38_row7_col3, #T_4dd38_row9_col0, #T_4dd38_row9_col1, #T_4dd38_row9_col2, #T_4dd38_row9_col3, #T_4dd38_row10_col0, #T_4dd38_row10_col1, #T_4dd38_row10_col2, #T_4dd38_row10_col3, #T_4dd38_row11_col0, #T_4dd38_row11_col1, #T_4dd38_row11_col2, #T_4dd38_row11_col3 {
#   color: blue;
# }
# </style>
# <table id="T_4dd38">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_4dd38_level0_col0" class="col_heading level0 col0" >2015</th>
#       <th id="T_4dd38_level0_col1" class="col_heading level0 col1" >2016</th>
# ...

# %%
#Maximum accidents per district higlighted in dark green
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')
s3.apply(highlight_max, props='color:white;background-color:darkgreen', axis=0)
# Out:
# <style type="text/css">
# #T_4dd38_row0_col0, #T_4dd38_row1_col0, #T_4dd38_row1_col1, #T_4dd38_row1_col2, #T_4dd38_row1_col3, #T_4dd38_row2_col0, #T_4dd38_row2_col1, #T_4dd38_row2_col2, #T_4dd38_row2_col3, #T_4dd38_row4_col0, #T_4dd38_row6_col0, #T_4dd38_row6_col3, #T_4dd38_row7_col0, #T_4dd38_row7_col1, #T_4dd38_row7_col2, #T_4dd38_row7_col3, #T_4dd38_row9_col0, #T_4dd38_row9_col1, #T_4dd38_row9_col2, #T_4dd38_row9_col3, #T_4dd38_row10_col0, #T_4dd38_row10_col1, #T_4dd38_row10_col2, #T_4dd38_row10_col3, #T_4dd38_row11_col0, #T_4dd38_row11_col1, #T_4dd38_row11_col2, #T_4dd38_row11_col3 {
#   color: blue;
# }
# #T_4dd38_row3_col0, #T_4dd38_row3_col1, #T_4dd38_row3_col2, #T_4dd38_row3_col3 {
#   color: white;
#   background-color: darkgreen;
# }
# </style>
# <table id="T_4dd38">
#   <thead>
#     <tr>
#       <th class="index_name level0" >YEAR</th>
#       <th id="T_4dd38_level0_col0" class="col_heading level0 col0" >2015</th>
# ...
